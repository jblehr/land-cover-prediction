# %% [markdown]
# This notebook is a shell to run code on Colab.

# %%
# Mount google drive and change directory
from google.colab import drive
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT, force_remount=True)
# %cd 'drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction'
# Out:
# /content/drive
# Mounted at /content/drive
# /content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction

# %%
# Setup Git, confirm we are in correct directory
# Set to correct values
# !git config --global user.email "jblehr@gmail.com"
# !git config --global user.name "Jacob Lehr"
# !git config --global user.email "GondekNP@gmail.com"
# !git config --global user.name "GondekNP"
# !git branch
# !ls

# %%
# Only library that does not come stock with Colab
# !pip install optuna
# !pip install opencv-python

# %%
# %cd scripts
# Out:
# /content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction/scripts

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import optuna
import convGRU
from optuna.trial import TrialState

name = 'initial_importance_test'
storage = f"sqlite:////content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction//output/{name}.db"

study = optuna.create_study(direction="minimize", study_name=name, storage=storage, load_if_exists=True)
study.optimize(convGRU.objective, n_trials=100)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

fig = optuna.visualization.plot_param_importances(study)
fig.show()
# Out:
# [I 2022-05-23 02:28:14,179] A new study created in RDB with name: initial_importance_test
# [W 2022-05-23 02:30:14,159] Trial 0 failed because of the following error: RuntimeError('Expected floating point type for target with class probabilities, got Long')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction/scripts/convGRU.py", line 434, in objective
#     loss = evaluation.get_loss(convGRU_mod, test_dataloader, criterion, cuda_)
#   File "/content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction/scripts/evaluation.py", line 64, in get_loss
#     loss = criterion(outputs_flat, targets_flat)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py", line 1165, in forward
#     label_smoothing=self.label_smoothing)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 2996, in cross_entropy
#     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
# RuntimeError: Expected floating point type for target with class probabilities, got Long
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-118ac97cfc13> in <module>()
#       7
#       8 study = optuna.create_study(direction="minimize", study_name=name, storage=storage, load_if_exists=True)
# ----> 9 study.optimize(convGRU.objective, n_trials=100)
#      10
#      11 pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     407             callbacks=callbacks,
#     408             gc_after_trial=gc_after_trial,
# --> 409             show_progress_bar=show_progress_bar,
#     410         )
#     411
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     262
#     263     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 264         raise func_err
#     265     return trial
#     266
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# /content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction/scripts/convGRU.py in objective(trial)
#     432
#     433     criterion=torch.nn.CrossEntropyLoss()
# --> 434     loss = evaluation.get_loss(convGRU_mod, test_dataloader, criterion, cuda_)
#     435     print('Initial test loss: ' + str(loss))
#     436
#
# /content/drive/Shareddrives/Adv-ML Project/repo/land-cover-prediction/scripts/evaluation.py in get_loss(model, dataloader, criterion, cuda_)
#      62
#      63
# ---> 64                 loss = criterion(outputs_flat, targets_flat)
#      65                 losses.append(float(loss))
#      66
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1163         return F.cross_entropy(input, target, weight=self.weight,
#    1164                                ignore_index=self.ignore_index, reduction=self.reduction,
# -> 1165                                label_smoothing=self.label_smoothing)
#    1166
#    1167
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    2994     if size_average is not None or reduce is not None:
#    2995         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2996     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    2997
#    2998
#
# RuntimeError: Expected floating point type for target with class probabilities, got Long
