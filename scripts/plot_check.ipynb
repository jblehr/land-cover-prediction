# %%
from skimage import io
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
image_path = '../data/processed/tif/planet/1311_3077_13_10N/2018-01-01.tif'
image = io.imread(image_path)

# %%
plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
new_min = -1
new_max = 1
rgb_im = image[:,:,:3]
image_normalized = (rgb_im - np.min(rgb_im)) / (
    np.max(rgb_im) - np.min(rgb_im)) * (new_max - new_min) + new_min

image_norm2 = ( rgb_im - np.min(rgb_im) ) * (new_max - new_min) / ( np.max(rgb_im) - np.min(rgb_im) ) + new_min

# %%
new_image = image.copy()
new_image[:,:,0] = image[:,:,2]
new_image[:,:,2] = image[:,:,0]

# %%
norm = np.zeros((1024,1024))
final = cv2.normalize(new_image,  norm, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

# %%
final.dtype
# Out:
# dtype('int16')

# %%
plt.imshow(final[:,:,:3])
